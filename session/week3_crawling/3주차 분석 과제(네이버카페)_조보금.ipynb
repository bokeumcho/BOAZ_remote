# %%
from selenium import webdriver
import time
browser = webdriver.Chrome('/Users/USER/Desktop/chromedriver.exe')

# %%
browser.get("https://nid.naver.com/nidlogin.login?mode=form&url=https://cafe.naver.com/boazbigdata")
id = browser.find_element_by_css_selector("#id").send_keys("bokeum83")
pw = browser.find_element_by_xpath('//*[@id="pw"]').send_keys("qhrqhf2160")

# %%
browser.find_element_by_css_selector("#frmNIDLogin > fieldset > input").click()
browser.find_element_by_xpath("//*[@id='frmNIDLogin']/fieldset/span[1]").click()

# %%
browser.find_element_by_css_selector("#login_maintain > span.btn_maintain > a").click()

# %%
browser.get("https://cafe.naver.com/boazbigdata")

# %%
from bs4 import BeautifulSoup
html  = browser.page_source

# %%
soup=BeautifulSoup(html,'lxml') 
soup
soup.prettify()
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html lang="ko" xmlns="http://www.w3.org/1999/xhtml">\n <head>\n  <meta content="noindex, nofollow" name="robots"/>\n  <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>\n  <title>\n   국내 최초 빅데이터 연합 동아리 BOAZ : 네이버 카페\n  </title>\n  <link href="/favicon.ico?2" rel="shortcut icon" type="image/x-icon"/>\n  <meta content="always" name="referrer"/>\n  <link href="/static/css/main/css/mycafe-common-1529341915000-57158.css" rel="stylesheet" type="text/css"/>\n  <link href="/static/css/main/css/mycafe-layout-1529863117000-61097.css" rel="stylesheet" type="text/css"/>\n  <link href="/static/css/main/css/mycafe-main-1529863117000-221118.css" rel="stylesheet" type="text/css"/>\n  <link href="/static/css/main/css/widget-1512652210000-14621.css" rel="stylesheet" type="text/css"/>\n  <link href="/static/css/
# ...

# %%
bokeums=soup.select("#group433 a.gm-tcol-c") 
bokeums
# Out:
# [<a class="gm-tcol-c" href="/ArticleList.nhn?search.clubid=26506451&amp;search.menuid=444&amp;search.boardtype=L" id="menuLink444" onclick="goMenu('444');clickcr(this, 'mnu.normal','','',event);" target="cafe_main">
#  						파이썬 기초1
#  					</a>,
#  <a class="gm-tcol-c" href="/ArticleList.nhn?search.clubid=26506451&amp;search.menuid=445&amp;search.boardtype=L" id="menuLink445" onclick="goMenu('445');clickcr(this, 'mnu.normal','','',event);" target="cafe_main">
#  						파이썬 기초2
#  					</a>,
#  <a class="gm-tcol-c" href="/ArticleList.nhn?search.clubid=26506451&amp;search.menuid=446&amp;search.boardtype=L" id="menuLink446" onclick="goMenu('446');clickcr(this, 'mnu.normal','','',event);" target="cafe_main">
#  						sql 과 파이썬 연동
#  					</a>,
#  <a class="gm-tcol-c" href="/ArticleList.nhn?search.clubid=26506451&amp;search.menuid=447&amp;search.boardtype=L" id="menuLink447" onclick="goMenu('447');clickcr(this, 'mnu.normal','','',event);" target="cafe_main">
#  						선형대수1
#  					</a>,
# ...

# %%
for bokeum in bokeums:
    print(bokeum.text)
# Out:
# 						파이썬 기초1
#
#
# 						파이썬 기초2
#
#
# 						sql 과 파이썬 연동
#
#
# 						선형대수1
#
#
# 						Cs강의
#
#
# 						포스코 AI
#
#
# 						SAS
#
#
# 						Rshiny 심화
#
#
# 						파이썬 웹 프로그래밍
#
#
# 						일러스트레이터
#
#
# 						R기초
#
#
# 						파이썬 심화
#
#
# 						파이썬 텍스트마이닝
#
#
# 						파이썬 크롤링
#
#
# 						딥러닝 기초
#
#
# 						인터렉티브 시각화
#
#
# 						선형대수2
#
#
# 						멘토멘티A조
#
#
# 						멘토멘티B조
#
#
# 						멘토멘티C조
#
#
# 						멘토멘티D조
#
#
# 						멘토멘티E조
#
#
# 						18-2(방학중)스터디 신청
